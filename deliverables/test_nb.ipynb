# %% [markdown]
# # Title

# %% [markdown]
# Description

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# ### Functions

# %% [markdown]
# ### Main Execution
